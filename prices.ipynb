# %%
#LINEAR REGRESSION WITH ONE VARIABLE
# HOME PRICE PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df= pd.read_csv('D:\\data science\\ml\\ml2\\home.csv')

# %%
# %matplotlib inline
plt.xlabel("area (sq ft)")
plt.ylabel("prices (US$)")
plt.scatter(df.area,df.price, color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# C:\Users\khush\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
reg.coef_
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# %matplotlib inline
plt.xlabel("area (sq ft)")
plt.ylabel("prices (US$)")
plt.scatter(df.area,df.price, color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
d=pd.read_csv('area.csv')

# %%
p=np.round(reg.predict(d[['area']]),2)
d['prices']=p

# %%
d.to_csv('prediction.csv',index=False)
